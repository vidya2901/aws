# %%
from PIL import Image
import s3fs

fs = s3fs.S3FileSystem()

# To List 5 files in your accessible bucket
fs.ls('s3://treetracker-training-images/freetown/')[:5]

# open it directly
with fs.open(f's3://treetracker-training-images/freetown/ANNOMURI/2020.10.24.14.05.53_8.435271666666667_-13.217341666666668_81dfe364-58ee-43ca-a125-f5b5d5fb2908_IMG_20201024_120256_2779653409864243275.jpg') as f:
    display(Image.open(f))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x768 at 0x7F0F19F0A7F0>
